# %% [markdown]
# # Opgaver
#
# Løs opgaverne i denne workbook.

# %% [markdown]
# # Opgave 1
#
# Brug `catch-except` til at validere input fra brugeren så brugeren indtaster et heltal.

# %%
# Bruger indtaster et tal
print("Vælg et tal 1-4")

input_accepted = False
while not input_accepted:
    valg = input("indtast et tal!")
    # indsæt fx din kode her

# Dette vil fejle hvis valg ikke er et heltal
if int(valg) == 1:
    pass

# %% [markdown]
# # Opgave 2
#
# Skriv en funktion `get_user_choice()` der
#
# - returnerer et heltal 1-4, eller
# - false hvis brugeren indtaster "q"
#
# Ret koden til at bruge funktionen nedenfor.

# %%
# Bruger indtaster et tal
print("Vælg et tal 1-4")
valg = get_user_choice()
# indsæt din kode her

# %% [markdown]
# # Opgave 3
#
# Lav en ny udgave af din funktion så man kan angive hvilke tal der er gyldige som input.
#
# ```
# valg = get_user_choice2([1,2,3,4])
# ```

# %%
# Bruger indtaster et tal
print("Vælg et tal 1-4")
valg = get_user_choice([1,2,3,4])
# indsæt din kode her

# %% [markdown]
# # Opgave 4
#
# Overvej om det er en god ide at hente brugerens `input` i din funktion?
#
# Omskriv funktionen så den modtager input og gyldige svarmuligheder som parametre.

# %%
# Skriv denne funktion færdig
def is_selection_valid(choice, options):
    return (int(choice)) in options

ok = False
while not ok:
    valg = input("indtast et tal 1-4")
    ok = is_selection_valid(valg, [1,2,3,4])

print(f"Choice {valg}")

# %% [markdown]
# # Opgave 5
#
# Skriv mindst 5 testcases med `assert` til din nye funktion fra opgave 4, fx
# i stil med
# ```
# assert is_selection_valid("3", [1,2,3,4]) == True
# ```

# %%
assert is_selection_valid("1", [1, 2, 3, 4]) == True
assert is_selection_valid("3", [1, 2, 3, 4]) == True
assert is_selection_valid("4", [1, 2, 3, 4]) == True
assert is_selection_valid("0", [1, 2, 3, 4]) == False
assert is_selection_valid("ABC", [1, 2, 3, 4]) == False
