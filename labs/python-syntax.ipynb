# %% [markdown]
# # Lab: Introduktion til python syntax
#
#
#
# Kør cellerne og løs opgaverne.
# Opret denne funktion:

# %%
def add_two_numbers(n1, n2):
    return n1 + n2
r = add_two_numbers(4, 6)
print(r)

# %% [markdown]
# ## Opgave: kommentarer
#
# Tilføj en docstring til din funktion som forklarer hvad den gør.
#
# https://www.geeksforgeeks.org/python/python-docstrings/

# %%
# Indsæt din kode her

# %% [markdown]
# ## Opgave: input
#
# Kig på eksemplet på
# https://skillzam.com/notes/pythonNotes.html
# og brug input til at få tal fra brugeren.
#
# Skriv koden i hånden.

# %%
# Indsæt din kode her

# %% [markdown]
# # Opgave: formatering af strings
#
# Formater output fra din funktion ligesom i eksemplet fra før.
# Brug ``print(f"")``

# %%
# Indsæt din kode her

# %% [markdown]
# # Opgave: flere parametre
#
# Omskriv funktionen så den kan lægge tre tal sammen.

# %%
# Indsæt din kode her
